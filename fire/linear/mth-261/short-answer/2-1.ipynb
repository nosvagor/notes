# %% [markdown]
# # 2.1 Matrix Addition, Scalar Multiplication, and Transposition
#
# ___

# %%
import numpy as np
from sympy import *

# %%
# Question 1
# I mean, we could add each element manually, but who likes arithmatic?

A = Matrix([
            [3,-3,0],
            [-7,6,-7],
            [3,-5,-4]
])
B = Matrix([
            [-7,10,7],
            [1,2,9],
            [10,-2,-6]
])

print(np.array(A+B))
# Out:
# [[-4 7 7]
#  [-6 8 2]
#  [13 -7 -10]]

# %%
# Question 2
# 🥱🥱🥱🥱🥱

A = Matrix([
            [4,-7,7,-2],
            [3,-7,7,-9]
])
B = Matrix([
            [1,4,-10,-5],
            [4,-3,-5,-8]
])

print(np.array(A+B))
# Out:
# [[5 -3 -3 -7]
#  [7 -10 2 -17]]

# %%
# Question 3
# Still pretty easy, just multiplication of each element, boring tho!

A = Matrix([
            [7,10,-3],
            [9,9,6],
            [-3,5,5]
])

# l = lambda, the scalar
l = 4

print(np.array(A*l))
print('\nScalar multiplcation is commutative (most of the time)!\n')
print(np.array(l*A))
# Out:
# [[28 40 -12]
#  [36 36 24]
#  [-12 20 20]]
#
# Scalar multiplcation is commutative (most of the time)!
#
# [[28 40 -12]
#  [36 36 24]
#  [-12 20 20]]

# %% [markdown]
# Notes for question 4:

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Wft, flipping along a diagonal? I can't see it. What was I thinking?
#
# Oh right, Wiki is awesome, check out this gif:

# %% [markdown]
# ![Matrix_transpose.gif](data:image/gif;base64,...)

# %%
# Question 4

# we don't have to use sympy 'Matrix', np.array([[],[],[]]) works as too.
# I think rref is part of the symp package, which does need 'Matrix()' version.

A = np.array([
              [-1,2,3],
              [-10,-4,-2],
              [-9,-10,3]
])

# transposing is easy, simply use .T! 
print('Orignal Matrix')
print(A) 
print('\nTranposed Matrix')
print(A.T)
print('\nBack to Orignal Matrix')
print(A.T.T)
# Out:
# Orignal Matrix
# [[ -1   2   3]
#  [-10  -4  -2]
#  [ -9 -10   3]]
#
# Tranposed Matrix
# [[ -1 -10  -9]
#  [  2  -4 -10]
#  [  3  -2   3]]
#
# Back to Orignal Matrix
# [[ -1   2   3]
#  [-10  -4  -2]
#  [ -9 -10   3]]

# %%
# Question 5

# Same as question 4, but this time I guess its giving us a long matrix

A = np.array([
              [-5,-3],
              [7,-10],
              [9,-9],
              [-5,-9]
])

print('\nTranposed Matrix')
print(A.T)
# Out:
# Tranposed Matrix
# [[ -5   7   9  -5]
#  [ -3 -10  -9  -9]]

# %%
# Question 6

# Take it back now, y'all

# a) 

A = np.array([
              [5,-1,2,10,6,-1],
              [-5,0,-4,-2,1,5],
])

A2 = np.array([
              [2,8,4,-5,-6,8],
              [-10,1,-10,-6,-3,8],
])

print('a)')
print(A+A2)

l = 4
B = np.array([
            [-3,10],
            [-2,1],
            [1,-7],
            [5,-5],
            [-1,4]
])

print('\nb)')
print(l*B)

C = np.array([
              [5,-4,-3,5],
              [0,1,-10,-1],
              [-9,-4,10,3]

])


print('\nc)')
print(C.T)
# Out:
# a)
# [[  7   7   6   5   0   7]
#  [-15   1 -14  -8  -2  13]]
#
# b)
# [[-12  40]
#  [ -8   4]
#  [  4 -28]
#  [ 20 -20]
#  [ -4  16]]
#
# c)
# [[  5   0  -9]
#  [ -4   1  -4]
#  [ -3 -10  10]
#  [  5  -1   3]]

# %%
# Question 7

# The key fact here is that dimensions (m x n) must match!

A = np.array([
              [-5,-1,-5],
              [-4,-4,1],
])

B = np.array([
              [-4,-2],
              [5,-2],
              [-1,-2]
])


C = np.array([
              [3,-1],
              [4,2],
              [-3,3]
])

# If any are invalid, then code will fail to run. Comment it out to continue!

print('a)')
print(-4*B+-5*C)

print('\nb)')
print(3*C+A.T)

# print('\nc)')
# print(-4B.T-C)
# Out:
# a)
# [[  1  13]
#  [-40  -2]
#  [ 19  -7]]
#
# b)
# [[  4  -7]
#  [ 11   2]
#  [-14  10]]
